# %%
import time, random
from pathlib import Path

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score, classification_report
from sklearn.svm import SVC

import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (Input, InputLayer, Conv1D, MaxPooling1D,
                                     BatchNormalization, LeakyReLU, Flatten,
                                     LSTM, GRU, Dense, Dropout)
from tensorflow.keras.utils import to_categorical
import scipy.sparse as sp
from spektral.utils.sparse import sp_matrix_to_sp_tensor
from spektral.layers import ChebConv, GlobalAvgPool

# Reproducibility -------------------------------------------------------------
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# Paths -----------------------------------------------------------------------
DATA_PATH = Path("emotions.csv")  # Change if needed
assert DATA_PATH.exists(), f"Could not find {DATA_PATH}."

# %% Load data ----------------------------------------------------------------

df = pd.read_csv(DATA_PATH)
print("Shape:", df.shape)
# Out:
# Shape: (2132, 2549)

# %%
# Heuristic label‑column detection
LABEL_COL = next((c for c in ["label", "emotion", "target", "class"] if c in df.columns), None)
if LABEL_COL is None:
    raise ValueError("Label column not detected - set LABEL_COL manually.")

X = df.drop(columns=LABEL_COL).astype("float32").values
labels = df[LABEL_COL].values

le = LabelEncoder()
y_int = le.fit_transform(labels)
num_classes = len(le.classes_)
print("Classes:", le.classes_)
# Out:
# Classes: ['NEGATIVE' 'NEUTRAL' 'POSITIVE']

# %%
y_cat = to_categorical(y_int, num_classes)

# Split -----------------------------------------------------------------------
X_train, X_test, y_train_int, y_test_int, y_train_cat, y_test_cat = train_test_split(
    X, y_int, y_cat, test_size=0.2, stratify=y_int, random_state=SEED)

# Scale (classical models + DL) ----------------------------------------------
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled  = scaler.transform(X_test)

# Reshape for sequence models -------------------------------------------------
n_features = X_train_scaled.shape[1]  # sequence length
X_train_seq = X_train_scaled.reshape((-1, n_features, 1))
X_test_seq  = X_test_scaled.reshape((-1, n_features, 1))

# %%
K_NEIGH = 8  # number of neighbours each node connects to
A_dense = np.zeros((n_features, n_features), dtype="float32")
for i in range(n_features):
    for j in range(1, K_NEIGH // 2 + 1):
        A_dense[i, (i + j) % n_features] = 1
        A_dense[i, (i - j) % n_features] = 1
A_dense += A_dense.T + np.eye(n_features, dtype="float32")

A_sparse_sp = sp.csr_matrix(A_dense)                    # SciPy CSR
A_sparse_tf = sp_matrix_to_sp_tensor(A_sparse_sp)       # TF SparseTensor

# %%
def compile_and_train(model, inputs, targets, val_data, epochs=30, batch_size=64, lr=1e-3):
    # weight_decay through kernel_regularizer if needed; quick Adam setup
    opt = tf.keras.optimizers.Adam(learning_rate=lr)
    model.compile(opt, loss="categorical_crossentropy", metrics=["accuracy"])
    t0 = time.time()
    model.fit(inputs, targets, validation_data=val_data,
              epochs=epochs, batch_size=batch_size, verbose=1)
    return time.time() - t0


def report(model, inputs, y_true_int, name="model"):
    y_pred_prob = model.predict(inputs, verbose=0)
    y_pred_int  = np.argmax(y_pred_prob, axis=1)
    acc = accuracy_score(y_true_int, y_pred_int)
    print(f"\n{name} – accuracy: {acc:.4f}\n")
    print(classification_report(y_true_int, y_pred_int, target_names=le.classes_))
    return acc

# %%
# Model builders --------------------------------------------------------------
def build_cnn(inp, classes):
    return Sequential([
        InputLayer(inp),
        Conv1D(64, 3, activation="relu"),
        MaxPooling1D(2),
        BatchNormalization(),
        Conv1D(128, 3, activation="relu"),
        MaxPooling1D(2),
        Flatten(),
        Dense(128, activation="relu"),
        Dropout(0.5),
        Dense(classes, activation="softmax"),
    ])


def build_lstm(inp, classes):
    return Sequential([
        InputLayer(inp),
        LSTM(128),
        Dropout(0.5),
        Dense(classes, activation="softmax"),
    ])


def build_gru(inp, classes):
    return Sequential([
        InputLayer(inp),
        GRU(128),
        Dropout(0.5),
        Dense(classes, activation="softmax"),
    ])


def build_cnn_lstm(inp, classes):
    return Sequential([
        InputLayer(inp),
        Conv1D(64, 3, activation="relu"),
        MaxPooling1D(2),
        BatchNormalization(),
        Conv1D(128, 3, activation="relu"),
        MaxPooling1D(2),
        LSTM(128),
        Dropout(0.5),
        Dense(classes, activation="softmax"),
    ])


def build_paper_cnn_lstm(inp, classes):
    m = Sequential()
    m.add(InputLayer(inp))
    for _ in range(10):
        m.add(Conv1D(64, 3, padding="same"))
        m.add(BatchNormalization())
        m.add(LeakyReLU(alpha=0.01))
        m.add(MaxPooling1D(2))
    m.add(Conv1D(64, 1))
    m.add(LSTM(128, return_sequences=True))
    m.add(LSTM(128, return_sequences=True))
    m.add(LSTM(128))
    m.add(Dense(100, activation="relu"))
    m.add(Dropout(0.5))
    m.add(Dense(classes, activation="softmax"))
    return m



class ChebConvNoMaskSparse(ChebConv):
    def __init__(self, *args, **kwargs):
        kwargs["sparse"] = True          # force sparse mode
        super().__init__(*args, **kwargs)

    def call(self, inputs):
        # Expect [X, A]; if mask sneaks in, drop it
        if isinstance(inputs, (list, tuple)) and len(inputs) == 3:
            inputs = inputs[:2]
        return super().call(inputs)

# ── DGCNN with *constant* adjacency ─────────────────────────────────────────
def build_dgcnn_constant(A_const_sparse, num_nodes, classes, channels=32):
    """
    A_const_sparse: tf.sparse.SparseTensor, shape = (num_nodes, num_nodes)
    """
    X_in = Input(shape=(num_nodes, 1), name="node_features")

    # Keras‑friendly way to inject a constant tensor into the graph:
    A_const = tf.keras.layers.Lambda(lambda _: A_const_sparse,
                                     name="const_adj")(X_in)

    x = ChebConvNoMaskSparse(channels, K=2, activation="relu")([X_in, A_const])
    x = Dropout(0.5)(x)
    x = GlobalAvgPool()(x)
    out = Dense(classes, activation="softmax")(x)
    return Model(inputs=X_in, outputs=out, name="DGCNN_constA")

# %%
results = []

# %%
# CNN -------------------------------------------------------------
name = "CNN"
print("\n==========", name ,"==========")
model = build_cnn((n_features, 1), num_classes)
model.summary()
rt = compile_and_train(model, X_train_seq, y_train_cat, (X_test_seq, y_test_cat), epochs=30)
acc = report(model, X_test_seq, y_test_int, name)
results.append((name, acc, rt))
# Out:
# ========== CNN ==========
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 2546, 64)       │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 1273, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1273, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 1271, 128)      │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 635, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 81280)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │    10,403,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              
30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.9687 - loss: 0.0797 - val_accuracy: 0.9672 - val_loss: 0.1226
# Epoch 25/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.9715 - loss: 0.0874 - val_accuracy: 0.9602 - val_loss: 0.1003
# Epoch 26/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.9841 - loss: 0.0590 - val_accuracy: 0.9836 - val_loss: 0.0905
# Epoch 27/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.9713 - loss: 0.0771 - val_accuracy: 0.9578 - val_loss: 0.1192
# Epoch 28/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.9793 - loss: 0.0589 - val_accuracy: 0.9649 - val_loss: 0.1563
# Epoch 29/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.9648 - loss: 0.1150 - val_accuracy: 0.9461 - val_loss: 0.1427
# Epoch 30/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.9742 - loss: 0.0777 - val_accuracy: 0.9742 - val_loss: 0.1078
#
# CNN – accuracy: 0.9742
#
#               precision    recall  f1-score   support
#
#     NEGATIVE       0.97      0.97      0.97       142
#      NEUTRAL       0.99      0.99      0.99       143
#     POSITIVE       0.96      0.96      0.96       142
#
#     accuracy                           0.97       427
#    macro avg       0.97      0.97      0.97       427
# weighted avg       0.97      0.97      0.97       427

# %%
# LSTM -------------------------------------------------------------
name = "LSTM"
print("\n==========", name ,"==========")
model = build_lstm((n_features, 1), num_classes)
model.summary()
rt = compile_and_train(model, X_train_seq, y_train_cat, (X_test_seq, y_test_cat), epochs=30)
acc = report(model, X_test_seq, y_test_int, name)
results.append((name, acc, rt))
# Out:
# ========== LSTM ==========
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 128)            │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 66,947 (261.51 KB)
#  Trainable params: 66,947 (261.51 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 112s 4s/step - accuracy: 0.4989 - loss: 1.0442 - val_accuracy: 0.5878 - val_loss: 0.7927
# Epoch 2/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 145s 4s/step - accuracy: 0.6293 - loss: 0.8073 - val_accuracy: 0.5902 - val_loss: 0.8623
# Epoch 3/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 116s 4s/step - accuracy: 0.6379 - loss: 0.7802 - val_accuracy: 0.8361 - val_loss: 0.6172
# Epoch 4/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 121s 4s/step - accuracy: 0.7192 - loss: 0.6700 - val_accuracy: 0.8103 - val_loss: 0.7955
# Epoch 5/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 123s 5s/step - accuracy: 0.7486 - loss: 0.8440 - val_accuracy: 0.7494 - val_loss: 0.6212
# Epoch 6/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 126s 5s/step - accuracy: 0.7243 - loss: 0.6740 - val_accuracy: 0.8735 - val_loss: 0.5484
# Epoch 7/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 126s 5s/step - accuracy: 0.7730 - loss: 0.6516 - val_accuracy: 0.7260 - val_loss: 0.7072
# Epoch 8/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 141s 5s/step - accuracy: 0.7438 - loss: 0.7329 - val_accuracy: 0.7799 - val_loss: 0.5482
# Epoch 9/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 125s 5s/step - accuracy: 0.7867 - loss: 0.6125 - val_accuracy: 0.8923 - val_loss: 0.4303
# Epoch 10/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 144s 5s/step - accuracy: 0.8369 - loss: 0.5043 - val_accuracy: 0.8712 - val_loss: 0.3488
# Epoch 11/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 141s 5s/step - accuracy: 0.8203 - loss: 0.4620 - val_accuracy: 0.8899 - val_loss: 0.3569
# Epoch 12/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 124s 5s/step - accuracy: 0.7991 - loss: 0.5650 - val_accuracy: 0.7986 - val_loss: 0.4823
# Epoch 13/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 124s 5s/step - accuracy: 0.7863 - loss: 0.5523 - val_accuracy: 0.8571 - val_loss: 0.4412
# Epoch 14/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 126s 5s/step - accuracy: 0.7901 - loss: 0.5214 - val_accuracy: 0.8759 - val_loss: 0.4557
# Epoch 15/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 141s 5s/step - accuracy: 0.8201 - loss: 0.5593 - val_accuracy: 0.8782 - val_loss: 0.4270
# Epoch 16/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 143s 5s/step - accuracy: 0.8382 - loss: 0.5127 - val_accuracy: 0.8595 - val_loss: 0.4057
# Epoch 17/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 126s 5s/step - accuracy: 0.8379 - loss: 0.4561 - val_accuracy: 0.8829 - val_loss: 0.3243
# Epoch 18/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 127s 5s/step - accuracy: 0.8417 - loss: 0.4499 - val_accuracy: 0.8735 - val_loss: 0.3414
# Epoch 19/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 143s 5s/step - accuracy: 0.8281 - loss: 0.4745 - val_accuracy: 0.8197 - val_loss: 0.4603
# Epoch 20/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 142s 5s/step - accuracy: 0.7945 - loss: 0.5230 - val_accuracy: 0.8946 - val_loss: 0.4147
# Epoch 21/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 127s 5s/step - accuracy: 0.8323 - loss: 0.4813 - val_accuracy: 0.8056 - val_loss: 0.6911
# Epoch 22/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 127s 5s/step - accuracy: 0.7877 - loss: 0.6476 - val_accuracy: 0.3747 - val_loss: 1.8482
# Epoch 23/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 143s 5s/step - accuracy: 0.4588 - loss: 1.3944 - val_accuracy: 0.5925 - val_loss: 0.8464
# Epoch 24/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 128s 5s/step - accuracy: 0.6497 - loss: 0.8365 - val_accuracy: 0.8571 - val_loss: 0.5342
# Epoch 25/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 128s 5s/step - accuracy: 0.7915 - loss: 0.6091 - val_accuracy: 0.8806 - val_loss: 0.4138
# Epoch 26/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 142s 5s/step - accuracy: 0.8331 - loss: 0.4780 - val_accuracy: 0.8876 - val_loss: 0.3261
# Epoch 27/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 141s 5s/step - accuracy: 0.8437 - loss: 0.4233 - val_accuracy: 0.7892 - val_loss: 0.4770
# Epoch 28/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 143s 5s/step - accuracy: 0.7749 - loss: 0.5382 - val_accuracy: 0.8665 - val_loss: 0.4763
# Epoch 29/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 141s 5s/step - accuracy: 0.8432 - loss: 0.4908 - val_accuracy: 0.8665 - val_loss: 0.4400
# Epoch 30/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 131s 4s/step - accuracy: 0.8342 - loss: 0.4594 - val_accuracy: 0.8829 - val_loss: 0.3510
#
# LSTM – accuracy: 0.8829
#
#               precision    recall  f1-score   support
#
#     NEGATIVE       0.84      0.89      0.86       142
#      NEUTRAL       0.95      0.97      0.96       143
#     POSITIVE       0.86      0.79      0.82       142
#
#     accuracy                           0.88       427
#    macro avg       0.88      0.88      0.88       427
# weighted avg       0.88      0.88      0.88       427

# %%
# GRU -------------------------------------------------------------
name = "GRU"
print("\n==========", name ,"==========")
model = build_gru((n_features, 1), num_classes)
model.summary()
rt = compile_and_train(model, X_train_seq, y_train_cat, (X_test_seq, y_test_cat), epochs=30)
acc = report(model, X_test_seq, y_test_int, name)
results.append((name, acc, rt))
# Out:
# ========== GRU ==========
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │
30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 190s 7s/step - accuracy: 0.8522 - loss: 0.3926 - val_accuracy: 0.9063 - val_loss: 0.3097
# Epoch 22/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 192s 7s/step - accuracy: 0.8554 - loss: 0.3677 - val_accuracy: 0.8993 - val_loss: 0.2937
# Epoch 23/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 203s 7s/step - accuracy: 0.8565 - loss: 0.3576 - val_accuracy: 0.8946 - val_loss: 0.3097
# Epoch 24/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 203s 7s/step - accuracy: 0.8554 - loss: 0.3748 - val_accuracy: 0.9087 - val_loss: 0.2764
# Epoch 25/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 191s 7s/step - accuracy: 0.8621 - loss: 0.3337 - val_accuracy: 0.8993 - val_loss: 0.2662
# Epoch 26/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 190s 7s/step - accuracy: 0.8694 - loss: 0.3304 - val_accuracy: 0.8923 - val_loss: 0.2813
# Epoch 27/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 202s 7s/step - accuracy: 0.8606 - loss: 0.3264 - val_accuracy: 0.8970 - val_loss: 0.2560
# Epoch 28/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 202s 7s/step - accuracy: 0.8626 - loss: 0.3375 - val_accuracy: 0.8970 - val_loss: 0.2506
# Epoch 29/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 201s 7s/step - accuracy: 0.8690 - loss: 0.3437 - val_accuracy: 0.8923 - val_loss: 0.2983
# Epoch 30/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 191s 7s/step - accuracy: 0.8720 - loss: 0.3210 - val_accuracy: 0.9087 - val_loss: 0.2561
#
# GRU – accuracy: 0.9087
#
#               precision    recall  f1-score   support
#
#     NEGATIVE       0.81      0.99      0.89       142
#      NEUTRAL       0.99      0.97      0.98       143
#     POSITIVE       0.96      0.76      0.85       142
#
#     accuracy                           0.91       427
#    macro avg       0.92      0.91      0.91       427
# weighted avg       0.92      0.91      0.91       427

# %%
# CNN-LSTM -------------------------------------------------------------
name = "CNN-LSTM"
print("\n==========", name ,"==========")
model = build_cnn_lstm((n_features, 1), num_classes)
model.summary()
rt = compile_and_train(model, X_train_seq, y_train_cat, (X_test_seq, y_test_cat), epochs=30)
acc = report(model, X_test_seq, y_test_int, name)
results.append((name, acc, rt))
# Out:
# ========== CNN-LSTM ==========
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_2 (Conv1D)               │ (None, 2546, 64)       │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 1273, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 1273, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 1271, 128)      │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 635, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 157,187 (614.01 KB)
#  Trainable params: 157,059 (613.51 KB)
#  Non-trainable params: 128 (512.00 B)
# Epoch 1/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 26s 897ms/step - accuracy: 0.7419 - loss: 0.6768 - val_accuracy: 0.4286 - val_loss: 1.1050
# Epoch 2/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 23s 862ms/step - accuracy: 0.8772 - loss: 0.3160 - val_accuracy: 0.4988 - val_loss: 1.1726
# Epoch 3/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 41s 861ms/step - accuracy: 0.8780 - loss: 0.2946 - val_accuracy: 0.5340 - val_loss: 1.0465
# Epoch 4/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 41s 870ms/step - accuracy: 0.8915 - loss: 0.2764 - val_accuracy: 0.5316 - val_loss: 0.9198
# Epoch 5/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━
30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 41s 859ms/step - accuracy: 0.9698 - loss: 0.0771 - val_accuracy: 0.9602 - val_loss: 0.1199
# Epoch 29/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 41s 857ms/step - accuracy: 0.9520 - loss: 0.1283 - val_accuracy: 0.9438 - val_loss: 0.1452
# Epoch 30/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 41s 857ms/step - accuracy: 0.9670 - loss: 0.0891 - val_accuracy: 0.9649 - val_loss: 0.1088
#
# CNN-LSTM – accuracy: 0.9649
#
#               precision    recall  f1-score   support
#
#     NEGATIVE       0.96      0.93      0.95       142
#      NEUTRAL       1.00      1.00      1.00       143
#     POSITIVE       0.93      0.96      0.95       142
#
#     accuracy                           0.96       427
#    macro avg       0.97      0.96      0.96       427
# weighted avg       0.97      0.96      0.96       427

# %%
# CNN-LSTM (paper) -------------------------------------------------------------
name = "CNN-LSTM (paper)"
print("\n==========", name ,"==========")
model = build_paper_cnn_lstm((n_features, 1), num_classes)
model.summary()
rt = compile_and_train(model, X_train_seq, y_train_cat, (X_test_seq, y_test_cat), epochs=30)
acc = report(model, X_test_seq, y_test_int, name)
results.append((name, acc, rt))
# Out:
# ========== CNN-LSTM (paper) ==========
# c:\Users\Elite\anaconda3\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_4 (Conv1D)               │ (None, 2548, 64)       │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 2548, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu (LeakyReLU)         │ (None, 2548, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_4 (MaxPooling1D)  │ (None, 1274, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 1274, 64)       │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 1274, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_1 (LeakyReLU)       │ (None, 1274, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_5 (MaxPooling1D)  │ (None, 637, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, 637, 64)        │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 637, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_2 (LeakyReLU)       │ (None, 637, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_6 (MaxPooling1D)  │ (None, 318, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 318, 64)        │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 318, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_3 (LeakyReLU)       │ (None, 318, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_7 (MaxPooling1D)  │ (None, 159, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_8 (Conv1D)               │ (None, 159, 64)        │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 159, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_4 (LeakyReLU)       │ (None, 159, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_8 (MaxPooling1D)  │ (None, 79, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_9 (Conv1D)               │ (None, 79, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 79, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_5 (LeakyReLU)       │ (None, 79, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_9 (MaxPooling1D)  │ (None, 39, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_10 (Conv1D)              │ (None, 39, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 39, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_6 (LeakyReLU)       │ (None, 39, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_10 (MaxPooling1D) │ (None, 19, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_11 (Conv1D)              │ (None, 19, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 19, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_7 (LeakyReLU)       │ (None, 19, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_11 (MaxPooling1D) │ (None, 9, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_12 (Conv1D)              │ (None, 9, 64)          │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 9, 64)          │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_8 (LeakyReLU)       │ (None, 9, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_12 (MaxPooling1D) │ (None, 4, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_13 (Conv1D)              │ (None, 4, 64)          │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 4, 64)          │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_9 (LeakyReLU)       │ (None, 4, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_13 (MaxPooling1D) │ (None, 2, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d
30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 1.0000 - loss: 1.8238e-04 - val_accuracy: 0.9906 - val_loss: 0.0588
# Epoch 23/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 1.0000 - loss: 1.6271e-04 - val_accuracy: 0.9930 - val_loss: 0.0557
# Epoch 24/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 1.0000 - loss: 1.4592e-04 - val_accuracy: 0.9930 - val_loss: 0.0530
# Epoch 25/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 1.0000 - loss: 1.1282e-04 - val_accuracy: 0.9930 - val_loss: 0.0506
# Epoch 26/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 1.0000 - loss: 1.0809e-04 - val_accuracy: 0.9930 - val_loss: 0.0501
# Epoch 27/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 1.0000 - loss: 9.0077e-05 - val_accuracy: 0.9930 - val_loss: 0.0481
# Epoch 28/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 1.0000 - loss: 8.3386e-05 - val_accuracy: 0.9930 - val_loss: 0.0474
# Epoch 29/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 1.0000 - loss: 6.5851e-05 - val_accuracy: 0.9930 - val_loss: 0.0473
# Epoch 30/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 1.0000 - loss: 7.2653e-05 - val_accuracy: 0.9953 - val_loss: 0.0449
#
# CNN-LSTM (paper) – accuracy: 0.9953
#
#               precision    recall  f1-score   support
#
#     NEGATIVE       1.00      0.99      0.99       142
#      NEUTRAL       1.00      1.00      1.00       143
#     POSITIVE       0.99      1.00      0.99       142
#
#     accuracy                           1.00       427
#    macro avg       1.00      1.00      1.00       427
# weighted avg       1.00      1.00      1.00       427

# %%
# SVM -------------------------------------------------------------
print("\n========== SVM (RBF) ==========")
svm = SVC(kernel="rbf", C=10, gamma="scale")
start = time.time()
svm.fit(X_train_scaled, y_train_int)
rt_svm = time.time() - start
svm_acc = accuracy_score(y_test_int, svm.predict(X_test_scaled))
print(f"SVM accuracy: {svm_acc:.4f}\n")
results.append(("SVM", svm_acc, rt_svm))
# Out:
# ========== SVM (RBF) ==========
# SVM accuracy: 0.9766

# %%
print("\n========== DGCNN (constant A) ==========")
dgcnn = build_dgcnn_constant(A_sparse_tf, n_features, num_classes)
dgcnn.summary()

# batch 64 now perfectly safe—only features in the batch dimension
rt_dg = compile_and_train(
    dgcnn,
    X_train_seq, y_train_cat,                  # X only!
    (X_test_seq, y_test_cat),
    epochs=20, batch_size=64, lr=1e-2
)

acc_dg = report(dgcnn, X_test_seq, y_test_int, "DGCNN")
results.append(("DGCNN", acc_dg, rt_dg))
# Out:
# ========== DGCNN (constant A) ==========
# WARNING:tensorflow:From c:\Users\Elite\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\core.py:204: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "DGCNN_constA"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ node_features       │ (None, 2548, 1)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ const_adj (Lambda)  │ (2548, 2548)      │          0 │ node_features[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ cheb_conv_no_mask_… │ (None, 2548, 32)  │         96 │ node_features[0]… │
# │ (ChebConvNoMaskSpa… │                   │            │ const_adj[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 2548, 32)  │          0 │ cheb_conv_no_mas… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_avg_pool     │ (None, 32)        │          0 │ dropout_5[0][0]   │
# │ (GlobalAvgPool)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 3)         │         99 │ global_avg_pool[… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 195 (780.00 B)
#  Trainable params: 195 (780.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.5483 - loss: 0.9687 - val_accuracy: 0.7143 - val_loss: 0.6792
# Epoch 2/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7225 - loss: 0.6697 - val_accuracy: 0.7166 - val_loss: 0.5767
# Epoch 3/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7468 - loss: 0.5725 - val_accuracy: 0.7471 - val_loss: 0.5124
# Epoch 4/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7723 - loss: 0.5111 - val_accuracy: 0.7916 - val_loss: 0.4523
# Epoch 5/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7965 - loss: 0.4614 - val_accuracy: 0.8080 - val_loss: 0.4192
# Epoch 6/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8221 - loss: 0.4262 - val_accuracy: 0.8056 - val_loss: 0.4021
# Epoch 7/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8352 - loss: 0.4034 - val_accuracy: 0.8197 - val_loss: 0.3826
# Epoch 8/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8482 - loss: 0.3833 - val_accuracy: 0.8314 - val_loss: 0.3649
# Epoch 9/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8524 - loss: 0.3684 - val_accuracy: 0.8384 - val_loss: 0.3487
# Epoch 10/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8523 - loss: 0.3548 - val_accuracy: 0.8454 - val_loss: 0.3424
# Epoch 11/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8613 - loss: 0.3469 - val_accuracy: 0.8501 - val_loss: 0.3309
# Epoch 12/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8580 - loss: 0.3407 - val_accuracy: 0.8548 - val_loss: 0.3243
# Epoch 13/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8649 - loss: 0.3311 - val_accuracy: 0.8712 - val_loss: 0.3125
# Epoch 14/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8660 - loss: 0.3228 - val_accuracy: 0.8712 - val_loss: 0.3078
# Epoch 15/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8643 - loss: 0.3149 - val_accuracy: 0.8665 - val_loss: 0.3023
# Epoch 16/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8675 - loss: 0.3172 - val_accuracy: 0.8595 - val_loss: 0.3064
# Epoch 17/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8580 - loss: 0.3193 - val_accuracy: 0.8665 - val_loss: 0.2931
# Epoch 18/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8704 - loss: 0.3052 - val_accuracy: 0.8759 - val_loss: 0.2850
# Epoch 19/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8759 - loss: 0.2904 - val_accuracy: 0.8806 - val_loss: 0.2840
# Epoch 20/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8708 - loss: 0.2928 - val_accuracy: 0.8759 - val_loss: 0.2725
#
# DGCNN – accuracy: 0.8759
#
#               precision    recall  f1-score   support
#
#     NEGATIVE       0.87      0.82      0.84       142
#      NEUTRAL       0.99      0.95      0.97       143
#     POSITIVE       0.79      0.86      0.82       142
#
#     accuracy                           0.88       427
#    macro avg       0.88      0.88      0.88       427
# weighted avg       0.88      0.88      0.88       427

# %%
# Results summary ------------------------------------------------------------
summary = (pd.DataFrame(results, columns=["Model", "Accuracy", "Train_Time_sec"])
             .sort_values("Accuracy", ascending=False))
print("\n=== Summary ===")
print(summary.to_string(index=False))
# Out:
# === Summary ===
#            Model  Accuracy  Train_Time_sec
# CNN-LSTM (paper)  0.995316      144.226198
#              SVM  0.976581        1.255781
#              CNN  0.974239      102.730754
#         CNN-LSTM  0.964871     1092.247870
#              GRU  0.908665     5904.657569
#             LSTM  0.882904     3967.158851
#            DGCNN  0.875878       12.015842
